# %%
# !ssh-keygen -t rsa -b 4096

# !ssh-keyscan -t rsa bitbucket.org >> ~/.ssh/known_hosts
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:4GcEfQmJ5B4GJpEFT7koTi1LDwC4oFI3nZ5BTSsHA+I root@834e54f6488d
# The key's randomart image is:
# +---[RSA 4096]----+
# |+ ==****oo .     |
# |+.o*+o=++.o      |
# |+oEo.+*o+.       |
# |==...+o*         |
# |=.=   o S        |
# | o .   o         |
# |                 |
# |                 |
# |                 |
# +----[SHA256]-----+
# # github.com:22 SSH-2.0-babeld-caed194f

# %%
# !cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... root@834e54f6488d

# %%
# !ssh -T -v git@bitbucket.org
# Out:
# ...
# Hi mahow0! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git clone git@bitbucket.org:fletcher2014/depression_model_attention_network.git
# Out:
# Cloning into 'HAN-pytorch-daicwoz'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 137 (delta 77), reused 87 (delta 27), pack-reused 0
# Receiving objects: 100% (137/137), 41.56 KiB | 599.00 KiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |█████████████                   | 834.1 MB 1.3 MB/s eta 0:14:55tcmalloc: large alloc 1147494400 bytes == 0x561f42004000 @  0x7fdefe310615 0x561f0952702c 0x561f0960717a 0x561f09529e4d 0x561f0961bc0d 0x561f0959e0d8 0x561f09598c35 0x561f0952b73a 0x561f0959df40 0x561f09598c35 0x561f0952b73a 0x561f0959a93b 0x561f0961ca56 0x561f09599fb3 0x561f0961ca56 0x561f09599fb3 0x561f0961ca56 0x561f09599fb3 0x561f0952bb99 0x561f0956ee79 0x561f0952a7b2 0x561f0959de65 0x561f09598c35 0x561f0952b73a 0x561f0959a93b 0x561f09598c35 0x561f0952b73a 0x561f09599b0e 0x561f0952b65a 0x561f09599d67 0x561f09598c35
# ...

# %%
# !cat ./HAN-pytorch-daicwoz/requirements.txt | xargs -n 1 pip install --ignore-installed
# Out:
# ...
#      |████████████████████████████████| 23.9 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 58 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 340 kB/s
# ...
#      |████████████████████████████████| 28.5 MB 90 kB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.21.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
#      |████████████████████████████████| 76 kB 3.7 MB/s
# ...

# %%
# !pip uninstall pytorch-ignite
# !pip install pytorch-ignite
# Out:
# Found existing installation: pytorch-ignite 0.4.6
# Uninstalling pytorch-ignite-0.4.6:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/ignite/*
#     /usr/local/lib/python3.7/dist-packages/pytorch_ignite-0.4.6.dist-info/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/ignite/ignite.py
# Proceed (y/n)? y
#   Successfully uninstalled pytorch-ignite-0.4.6
# ...
#   Using cached pytorch_ignite-0.4.6-py3-none-any.whl (232 kB)
# ...

# %%
# !python HAN-pytorch-daicwoz//src/main.py --train_csv_path ./drive/MyDrive/depression_text/LABELS/train_split_Depression_AVEC2017.csv --val_csv_path ./drive/MyDrive/depression_text/LABELS/dev_split_Depression_AVEC2017.csv  --eval_csv_path drive/MyDrive/depression_text/LABELS/full_test_split.csv --transcript_path ./drive/MyDrive/depression_text/TRANSCRIPT  --num_epochs 20 --lr 0.015
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# tcmalloc: large alloc 3600007168 bytes == 0x55ed8063e000 @  0x7f9ce2923001 0x7f9c863f5a0f 0x7f9c8644c113 0x7f9c8644cf77 0x7f9c864eee83 0x55ed77a9efcc 0x55ed77a9eda0 0x55ed77b13868 0x55ed77b0dc35 0x55ed77aa0fec 0x55ed77ae1bc9 0x55ed77adeac4 0x55ed77a9f8a9 0x55ed77b13b0a 0x55ed77b0dc35 0x55ed77aa073a 0x55ed77b0f93b 0x55ed77b0dc35 0x55ed77aa073a 0x55ed77b0f93b 0x55ed77aa065a 0x55ed77b12f40 0x55ed77b0dc35 0x55ed77aa073a 0x55ed77b12f40 0x55ed77aa065a 0x55ed77b0eb0e 0x55ed77b0dc35 0x55ed77b0d933 0x55ed77bd7402 0x55ed77bd777d
# cuda
# 100% 154/154 [00:01<00:00, 142.66it/s]
# ...

# %%
# !python /content/HAN-pytorch-daicwoz/src/grid_search.py
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                      [1],
#                                                      [1]], device='cuda:0')
# ic| labels: tensor([0., 1., 0., 0., 1., 1., 1., 0.], device='cuda:0')
# Epoch: 12/20:  15% 3/20 [00:06<00:36,  2.14s/it, Batch=2/20, Loss=0.712]ic| torch.max(logits,dim=1,keepdim=True)[1]: tensor([[1],
#                                                      [1],
#                                                      [1],
#                                                      [1],
#                                                      [1],
#                                                      [1],
#                                                      [1],
#                                                      [1]], device='cuda:0')
# ic| labels: tensor([0., 1., 1., 0., 1., 0., 0., 0.], device='cuda:0')
# ...

# %%
# Out:
# [0.05 0.06 0.07 0.08 0.09 0.1  0.11 0.12 0.13 0.14 0.15 0.16 0.17 0.18
#  0.19 0.2  0.21 0.22 0.23 0.24 0.25 0.26 0.27 0.28 0.29 0.3  0.31 0.32
#  0.33 0.34 0.35 0.36 0.37 0.38 0.39 0.4  0.41 0.42 0.43 0.44 0.45 0.46
#  0.47 0.48 0.49]

# %%
import torch

a = torch.Tensor([[True, False, False], [False, True, True], [True, True, True]]).bool()
print(torch.sum(a, dim=1))
# Out:
# tensor([1, 2, 3])

# %%
# !cd /content/HAN-pytorch-daicwoz/ && git config --global user.email "xquisitor@gmail.com" && git config --global user.name "mahow0" && git add . && git commit -m 'Grid search now stores results in file' && git push origin colab-friendly
# Out:
# [colab-friendly 7d4bb88] Grid search now stores results in file
#  10 files changed, 7 insertions(+), 1 deletion(-)
# Counting objects: 16, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (16/16), 11.68 KiB | 11.68 MiB/s, done.
# Total 16 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To github.com:mahow0/HAN-pytorch-daicwoz.git
#    e6f8dcd..7d4bb88  colab-friendly -> colab-friendly
